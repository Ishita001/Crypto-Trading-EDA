# %% [markdown]
# 5/1/22, 11:11 AM Crypto Trading and Analysis (EDA)
#
# > **Crypto Trading and Analysis (EDA)**
# >
# > **Motivation:**
# >
# > **Crypto Market has coins which are highly volatile in nature. Bitcoin
# > itself was around 5K in 2013 and by the year 2021 it reached to 48
# > Lakhs which itself shows how volatile the market is. The dataset
# > provides some interesting and valuable insights which help us in
# > gathering some usefull knowledge. Being a data scientist we are very
# > keen to understand such a market who data is not at all stable and
# > keeps on changing frequently and making out new patterns with changing
# > time. These introduction of new patterns with the time makes this
# > problem itself a interesting one and keeps on motivating us to find
# > some valuable information.**
# >
# > **Developed By:**
#
# <img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image1.png" style="width:0.125in;height:0.84722in" />
#
# > Mohit Kumar
# >
# > Sahithi Priya Gurram
# >
# > Ishita Agarwal
# >
# > Praneeth Gadipudi
# >
# > **Index:**
#
# <img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image2.png" style="width:0.125in;height:1.06944in" />
#
# > 1\. Installing Necessary Libraries
# >
# > 1\. Importing Necessary Libraries
# >
# > 1\. Importing the Dataset
# >
# > 1\. Statistical Description of the Dataset
# >
# > 1\. Data
# > Preprocessing<img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image3.png" style="width:9.83333in;height:0.51389in" />
# >
# > **1.) Installing Necessary Libraries**
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [2]:</p>
# </blockquote></td>
# <td><blockquote>
# <p><strong>!</strong>pip install pandas</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > Requirement already satisfied: pandas in
# > c:\\users\\mohit\\anaconda3\\lib\\site-packages (1.3.4)
# > Requirement already satisfied: numpy\>=1.17.3 in
# > c:\\users\\mohit\\anaconda3\\lib\\site-packages (from pandas) (1.20.3)
#
# localhost:8888/nbconvert/html/Data_Web_Mining/Project/Crypto Trading and
# Analysis (EDA).ipynb?download=false 1/14
#
# |                  |                                   |
# |------------------|-----------------------------------|
# | 5/1/22, 11:11 AM | Crypto Trading and Analysis (EDA) |
#
# > Requirement already satisfied: pytz\>=2017.3 in
# > c:\\users\\mohit\\anaconda3\\lib\\site-packages (from pandas)
# > (2021.3)
# > Requirement already satisfied: python-dateutil\>=2.7.3 in
# > c:\\users\\mohit\\anaconda3\\lib\\site-packages (from pandas) (2.8.2)
# > Requirement already satisfied: six\>=1.5 in
# > c:\\users\\mohit\\anaconda3\\lib\\site-packages (from
# > python-dateutil\>=2.7.3-\>pandas) (1.16.
# >
# > 0\)
# >
# > **2.) Importing Necessary Libraries**
#
# <table>
# <thead>
# <tr class="header">
# <th>In [2]:</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>In [3]:</td>
# <td></td>
# </tr>
# <tr class="even">
# <td>Out[3]:</td>
# <td><blockquote>
# <p>&lt;Figure size 1440x720 with 0 Axes&gt;</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p><strong>import</strong> pandas <strong>as</strong> pd<br />
# <strong>from</strong> scipy.stats <strong>import</strong> pearsonr<br />
# <strong>import</strong> matplotlib.pyplot <strong>as</strong> plt<br />
# <strong>import</strong> numpy <strong>as</strong> np</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p><em># setting matplotlib screen for vsiualizations</em><br />
# plt<strong>.</strong>figure(figsize<strong>=</strong>(20,10))</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > \<Figure size 1440x720 with 0 Axes\>
# >
# > **3.) Importing the Dataset**
#
# <table>
# <thead>
# <tr class="header">
# <th>In [4]:</th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>In [5]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>Out[5]:</td>
# <td><strong>SNo</strong></td>
# <td><blockquote>
# <p><strong>Name</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p><strong>Symbol</strong></p>
# </blockquote></td>
# <td><strong>Date</strong></td>
# <td><strong>High</strong></td>
# <td><strong>Low</strong></td>
# <td><strong>Open</strong></td>
# <td><strong>Close</strong></td>
# <td><strong>Volume</strong></td>
# <td><blockquote>
# <p><strong>Marketcap</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p><strong>Adjacent Close</strong></p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>2888</strong></td>
# <td>2889</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>02-07-2021 23:59</td>
# <td>0.667287</td>
# <td>0.634726</td>
# <td>0.659890</td>
# <td>0.656763</td>
# <td>2.061607e+09</td>
# <td>3.030759e+10</td>
# <td><blockquote>
# <p>0.656763</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>2889</strong></td>
# <td>2890</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>03-07-2021 23:59</td>
# <td>0.683677</td>
# <td>0.644653</td>
# <td>0.655639</td>
# <td>0.672888</td>
# <td>1.872820e+09</td>
# <td>3.105172e+10</td>
# <td><blockquote>
# <p>0.672888</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>
td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <thead>
# <tr class="header">
# <th>5/1/22, 11:11 AM</th>
# <th>Crypto Trading and Analysis (EDA)</th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>Out[8]:</td>
# <td><blockquote>
# <p>7 Close 2893 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>8 Volume 2893 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>9 Marketcap 2893 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>10 Adjacent Close 2893 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>dtypes: float64(7), int64(1), object(3)</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>memory usage: 248.7+ KB</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>((2893, 11), None)</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>In [9]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>Out[9]:</td>
# <td><strong>SNo</strong></td>
# <td><strong>High</strong></td>
# <td><strong>Low</strong></td>
# <td><strong>Open</strong></td>
# <td><strong>Close</strong></td>
# <td><strong>Volume</strong></td>
# <td><blockquote>
# <p><strong>Marketcap</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p><strong>Adjacent Close</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>count</strong></td>
# <td>2893.000000</td>
# <td>2893.000000</td>
# <td>2893.000000</td>
# <td>2893.000000</td>
# <td>2893.000000</td>
# <td>2.893000e+03</td>
# <td>2.893000e+03</td>
# <td><blockquote>
# <p>2893.000000</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>mean</strong></td>
# <td>1447.000000</td>
# <td>0.246591</td>
# <td>0.222000</td>
# <td>0.234548</td>
# <td>0.234790</td>
# <td>1.260299e+09</td>
# <td>9.678506e+09</td>
# <td><blockquote>
# <p>0.234790</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>std</strong></td>
# <td><blockquote>
# <p>835.281489</p>
# </blockquote></td>
# <td>0.365393</td>
# <td>0.311581</td>
# <td>0.338544</td>
# <td>0.338629</td>
# <td>3.137958e+09</td>
# <td>1.385907e+10</td>
# <td><blockquote>
# <p>0.338629</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>min</strong></td>
# <td>1.000000</td>
# <td>0.003082</td>
# <td>0.002802</td>
# <td>0.002809</td>
# <td>0.002810</td>
# <td>0.000000e+00</td>
# <td>2.196991e+07</td>
# <td><blockquote>
# <p>0.002810</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>25%</strong></td>
# <td><blockquote>
# <p>724.000000</p>
# </blockquote></td>
# <td>0.007531</td>
# <td>0.007093</td>
# <td>0.007332</td>
# <td>0.007346</td>
# <td>4.780950e+05</td>
# <td>2.263168e+08</td>
# <td><blockquote>
# <p>0.007346</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>50%</strong></td>
# <td>1447.000000</td>
# <td>0.189184</td>
# <td>0.176196</td>
# <td>0.181968</td>
# <td>0.182608</td>
# <td>1.119370e+08</td>
# <td>7.523251e+09</td>
# <td><blockquote>
# <p>0.182608</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>75%</strong></td>
# <td>2170.000000</td>
# <td>0.320751</td>
# <td>0.303941</td>
# <td>0.312021</td>
# <td>0.312465</td>
# <td>1.238721e+09</td>
# <td>1.306444e+10</td>
# <td><blockquote>
# <p>0.312465</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>max</strong></td>
# <td>2893.000000</td>
# <td>3.841940</td>
# <td>3.117340</td>
# <td>3.363570</td>
# <td>3.377810</td>
# <td>3.695518e+10</td>
# <td>1.308530e+11</td>
# <td><blockquote>
# <p>3.377810</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>xrp_data<strong>.</strong>describe()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **So, from here we can observe that from the year 2013 to 2021.**
# >
# > **XRP attained a minimum value of 0.002802 USD which in INR is
# > approximately Rs 0.21**
# >
# > **XRP attained a maximum value of 3.841940 USD which is INR is
# > approximately Rs 292**
#
# |            |     |
# |------------|-----|
# | In \[10\]: |     |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>btc_data<strong>.</strong>shape, btc_data<strong>.</strong>info()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > \<class 'pandas.core.frame.DataFrame'\>
# > RangeIndex: 2991 entries, 0 to 2990
# > Data columns (total 11 columns):
# > \# Column Non-Null Count Dtype
# > --- ------ -------------- -----
# > 0 SNo 2991 non-null int64
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>localhost:8888/nbconvert/html/Data_Web_Mining/Project/Crypto Trading and Analysis (EDA).ipynb?download=false</p>
# </blockquote></td>
# <td>4/14</td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <thead>
# <tr class="header">
# <th>5/1/22, 11:11 AM</th>
# <th>Crypto Trading and Analysis (EDA)</th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>Out[10]:</td>
# <td><blockquote>
# <p>1 Name 2991 non-null object</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>2 Symbol 2991 non-null object</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>3 Date 2991 non-null object</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>4 High 2991 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>5 Low 2991 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>6 Open 2991 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>7 Close 2991 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>8 Volume 2991 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>9 Marketcap 2991 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>10 Adjacent Close 2991 non-null float64</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>dtypes: float64(7), int64(1), object(3)</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>memory usage: 257.2+ KB</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>((2991, 11), None)</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>In [11]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>Out[11]:</td>
# <td><strong>SNo</strong></td>
# <td><strong>High</strong></td>
# <td><strong>Low</strong></td>
# <td><strong>Open</strong></td>
# <td><strong>Close</strong></td>
# <td><strong>Volume</strong></td>
# <td><blockquote>
# <p><strong>Marketcap</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p><strong>Adjacent Close</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>count</strong></td>
# <td>2991.000000</td>
# <td><blockquote>
# <p>2991.000000</p>
# </blockquote></td>
# <td><blockquote>
# <p>2991.000000</p>
# </blockquote></td>
# <td><blockquote>
# <p>2991.000000</p>
# </blockquote></td>
# <td><blockquote>
# <p>2991.000000</p>
# </blockquote></td>
# <td>2.991000e+03</td>
# <td>2.991000e+03</td>
# <td><blockquote>
# <p>2991.000000</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>mean</strong></td>
# <td>1496.000000</td>
# <td><blockquote>
# <p>6893.326038</p>
# </blockquote></td>
# <td><blockquote>
# <p>6486.009539</p>
# </blockquote></td>
# <td><blockquote>
# <p>6700.146240</p>
# </blockquote></td>
# <td><blockquote>
# <p>6711.290443</p>
# </blockquote></td>
# <td>1.090633e+10</td>
# <td>1.208761e+11</td>
# <td><blockquote>
# <p>6711.290443</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>std</strong></td>
# <td><blockquote>
# <p>863.571653</p>
# </blockquote></td>
# <td>11642.832456</td>
# <td>10869.032130</td>
# <td>11288.043736</td>
# <td>11298.141921</td>
# <td>1.888895e+10</td>
# <td>2.109438e+11</td>
# <td><blockquote>
# <p>11298.141921</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>min</strong></td>
# <td>1.000000</td>
# <td>74.561096</td>
# <td>65.526001</td>
# <td>68.504997</td>
# <td>68.431000</td>
# <td>0.000000e+00</td>
# <td>7.784112e+08</td>
# <td><blockquote>
# <p>68.431000</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>25%</strong></td>
# <td><blockquote>
# <p>748.500000</p>
# </blockquote></td>
# <td><blockquote>
# <p>436.179001</p>
# </blockquote></td>
# <td><blockquote>
# <p>422.879486</p>
# </blockquote></td>
# <td><blockquote>
# <p>430.445496</p>
# </blockquote></td>
# <td><blockquote>
# <p>430.569489</p>
# </blockquote></td>
# <td>3.036725e+07</td>
# <td>6.305579e+09</td>
# <td><blockquote>
# <p>430.569489</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>50%</strong></td>
# <td>1496.000000</td>
# <td><blockquote>
# <p>2387.610107</p>
# </blockquote></td>
# <td><blockquote>
# <p>2178.500000</p>
# </blockquote></td>
# <td><blockquote>
# <p>2269.889893</p>
# </blockquote></td>
# <td><blockquote>
# <p>2286.409912</p>
# </blockquote></td>
# <td>9.460360e+08</td>
# <td>3.741503e+10</td>
# <td><blockquote>
# <p>2286.409912</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>75%</strong></td>
# <td>2243.500000</td>
# <td><blockquote>
# <p>8733.926948</p>
# </blockquote></td>
# <td><blockquote>
# <p>8289.800460</p>
# </blockquote></td>
# <td><blockquote>
# <p>8569.656493</p>
# </blockquote></td>
# <td><blockquote>
# <p>8576.238715</p>
# </blockquote></td>
# <td>1.592015e+10</td>
# <td>1.499960e+11</td>
# <td><blockquote>
# <p>8576.238715</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>max</strong></td>
# <td>2991.000000</td>
# <td>64863.098910</td>
# <td>62208.964370</td>
# <td>63523.754870</td>
# <td>63503.457930</td>
# <td>3.509680e+11</td>
# <td>1.186360e+12</td>
# <td><blockquote>
# <p>63503.457930</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>btc_data<strong>.</strong>describe()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **So, from here we can observe that from the year 2013 to 2021.**
# >
# > **BTC attained a minimum value of 65.526001 USD which in INR is
# > approximately Rs 5000**
# >
# > **BTC attained a maximum value of 62208.964370 USD which is INR is
# > approximately Rs 48,00,000**
# >
# > **5.) Data Preprocessing**
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>localhost:8888/nbconvert/html/Data_Web_Mining/Project/Crypto Trading and Analysis (EDA).ipynb?download=false</p>
# </blockquote></td>
# <td>5/14</td>
# </tr>
# </tbody>
# </table>
#
# |                  |                                   |
# |------------------|-----------------------------------|
# | 5/1/22, 11:11 AM | Crypto Trading and Analysis (EDA) |
#
# > **For data preprocessing we will we doing the following:**
# >
# > 1\. Data Cleaning
# >
# > 1\. Data Reduction
# >
# > **a.) Data Cleaning**
# > **Cleaning the data by finding all the NA values and filling it**
# >
# > **We will try interpolating the dataset**
# >
# > **Interpolating : Taking the average value to the above and below
# > valid value. Meaning to say that trying to fit in between the above
# > and the below valid value.**
#
# <table>
# <thead>
# <tr class="header">
# <th>In
td>
# <td>Bitcoin</td>
# <td>BTC</td>
# <td>05-07-2021 23:59</td>
# <td>35284.34443</td>
# <td>33213.66103</td>
# <td>35284.34443</td>
# <td>33746.00246</td>
# <td>2.672155e+10</td>
# <td>6.326960e+11</td>
# <td><blockquote>
# <p>33746.00246</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>2990</strong></td>
# <td>2991</td>
# <td>Bitcoin</td>
# <td>BTC</td>
# <td>06-07-2021 23:59</td>
# <td>35038.53636</td>
# <td>33599.91617</td>
# <td>33723.50966</td>
# <td>34235.19345</td>
# <td>2.650126e+10</td>
# <td>6.418990e+11</td>
# <td><blockquote>
# <p>34235.19345</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **(b) Data Reduction**
# >
# > **So, we wlll dropping few attributes which are redudant or have
# > similarity with other attributes. In order to do so we will use
# > Pearson Correlation Coeffecient between two columns.**
# >
# > **On Observing the above dataset, the Close and Adjacent Close appears
# > to be the same.**
# >
# > **So, to ensure that the above mentioned attributes are the same we
# > will use correlation analysis.**
#
# <table>
# <thead>
# <tr class="header">
# <th>In [14]:</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>Out[14]:</td>
# <td><blockquote>
# <p>1.0</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>In [15]:</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>Out[15]:</td>
# <td><blockquote>
# <p>1.0</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>corr, _ <strong>=</strong> pearsonr(xrp_data['Close'], xrp_data['Adjacent Close'])<br />
# corr <strong>=</strong> round(corr,3)<br />
# corr</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>corr, _ <strong>=</strong> pearsonr(btc_data['Close'], btc_data['Adjacent Close'])<br />
# corr <strong>=</strong> round(corr,3)<br />
# corr</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > **So, from above we can see that both Close and Adjacent Close are
# > exactly same attributes as their r value is exactly 1. So we will drop
# > Adjacent Close from both XRP and BTC**
#
# <table>
# <thead>
# <tr class="header">
# <th>In [16]:</th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>Out[16]:</td>
# <td><strong>SNo</strong></td>
# <td><blockquote>
# <p><strong>Name</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p><strong>Symbol</strong></p>
# </blockquote></td>
# <td><strong>Date</strong></td>
# <td><strong>High</strong></td>
# <td><strong>Low</strong></td>
# <td><strong>Open</strong></td>
# <td><strong>Close</strong></td>
# <td><strong>Volume</strong></td>
# <td><blockquote>
# <p><strong>Marketcap</strong></p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><strong>2888</strong></td>
# <td>2889</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>02-07-2021 23:59</td>
# <td>0.667287</td>
# <td>0.634726</td>
# <td>0.659890</td>
# <td>0.656763</td>
# <td>2.061607e+09</td>
# <td><blockquote>
# <p>3.030759e+10</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><strong>2889</strong></td>
# <td>2890</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>03-07-2021 23:59</td>
# <td>0.683677</td>
# <td>0.644653</td>
# <td>0.655639</td>
# <td>0.672888</td>
# <td>1.872820e+09</td>
# <td><blockquote>
# <p>3.105172e+10</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>localhost:8888/nbconvert/html/Data_Web_Mining/Project/Crypto Trading and Analysis (EDA).ipynb?download=false</p>
# </blockquote></td>
# <td>7/14</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>xrp_data<strong>.</strong>drop(['Adjacent Close'], axis <strong>=</strong>1, inplace<strong>=True</strong>)<br />
# xrp_data<strong>.</strong>tail()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <thead>
# <tr class="header">
# <th>5/1/22, 11:11 AM</th>
# <th>Crypto Trading and Analysis (EDA)</th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td><strong>SNo</strong></td>
# <td><strong>Name</strong></td>
# <td><strong>Symbol</strong></td>
# <td><strong>Date</strong></td>
# <td><strong>High</strong></td>
# <td><blockquote>
# <p><strong>Low</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p><strong>Open</strong></p>
# </blockquote></td>
# <td><strong>Close</strong></td>
# <td><strong>Volume</strong></td>
# <td><blockquote>
# <p><strong>Marketcap</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>2890</strong></td>
# <td>2891</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>04-07-2021 23:59</td>
# <td>0.707783</td>
# <td>0.665802</td>
# <td>0.673218</td>
# <td>0.694945</td>
# <td>1.885242e+09</td>
# <td><blockquote>
# <p>3.206960e+10</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>2891</strong></td>
# <td>2892</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>05-07-2021 23:59</td>
# <td>0.695653</td>
# <td>0.648492</td>
# <td>0.695653</td>
# <td>0.654300</td>
# <td>2.076373e+09</td>
# <td><blockquote>
# <p>3.019395e+10</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>2892</strong></td>
# <td>2893</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>06-07-2021 23:59</td>
# <td>0.679923</td>
# <td>0.652676</td>
# <td>0.653055</td>
# <td>0.665402</td>
# <td>1.938959e+09</td>
# <td><blockquote>
# <p>3.072284e+10</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>In [17]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>Out[17]:</td>
# <td><strong>SNo</strong></td>
# <td><strong>Name</strong></td>
# <td><strong>Symbol</strong></td>
# <td><strong>Date</strong></td>
# <td><strong>High</strong></td>
# <td><strong>Low</strong></td>
# <td><strong>Open</strong></td>
# <td><strong>Close</strong></td>
# <td><strong>Volume</strong></td>
# <td><blockquote>
# <p><strong>Marketcap</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>2986</strong></td>
# <td>2987</td>
# <td>Bitcoin</td>
# <td>BTC</td>
# <td>02-07-2021 23:59</td>
# <td>33939.58870</td>
# <td>32770.68078</td>
# <td>33549.60018</td>
# <td>33897.04859</td>
# <td><blockquote>
# <p>3.872897e+10</p>
# </blockquote></td>
# <td><blockquote>
# <p>6.354510e+11</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>2987</strong></td>
# <td>2988</td>
# <td>Bitcoin</td>
# <td>BTC</td>
# <td
p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p><em>#Creating a historical return column for XRP</em><br />
# xrp_data['Return']<strong>=</strong> xrp_data['Close']<strong>.</strong>pct_change()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# <table>
# <thead>
# <tr class="header">
# <th>5/1/22, 11:11 AM</th>
# <th>Crypto Trading and Analysis (EDA)</th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>In [23]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>Out[23]:</td>
# <td><strong>SNo</strong></td>
# <td><blockquote>
# <p><strong>Name</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p><strong>Symbol</strong></p>
# </blockquote></td>
# <td><strong>Date</strong></td>
# <td><strong>High</strong></td>
# <td><strong>Low</strong></td>
# <td><strong>Open</strong></td>
# <td><strong>Close</strong></td>
# <td><strong>Volume</strong></td>
# <td><blockquote>
# <p><strong>Marketcap</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p><strong>Return</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>2888</strong></td>
# <td>2889</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>02-07-2021 23:59</td>
# <td>0.667287</td>
# <td>0.634726</td>
# <td>0.659890</td>
# <td>0.656763</td>
# <td>2.061607e+09</td>
# <td>3.030759e+10</td>
# <td><blockquote>
# <p>-0.006681</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>2889</strong></td>
# <td>2890</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>03-07-2021 23:59</td>
# <td>0.683677</td>
# <td>0.644653</td>
# <td>0.655639</td>
# <td>0.672888</td>
# <td>1.872820e+09</td>
# <td>3.105172e+10</td>
# <td><blockquote>
# <p>0.024553</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>2890</strong></td>
# <td>2891</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>04-07-2021 23:59</td>
# <td>0.707783</td>
# <td>0.665802</td>
# <td>0.673218</td>
# <td>0.694945</td>
# <td>1.885242e+09</td>
# <td>3.206960e+10</td>
# <td><blockquote>
# <p>0.032780</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>2891</strong></td>
# <td>2892</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>05-07-2021 23:59</td>
# <td>0.695653</td>
# <td>0.648492</td>
# <td>0.695653</td>
# <td>0.654300</td>
# <td>2.076373e+09</td>
# <td>3.019395e+10</td>
# <td><blockquote>
# <p>-0.058487</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>2892</strong></td>
# <td>2893</td>
# <td>XRP</td>
# <td>XRP</td>
# <td>06-07-2021 23:59</td>
# <td>0.679923</td>
# <td>0.652676</td>
# <td>0.653055</td>
# <td>0.665402</td>
# <td>1.938959e+09</td>
# <td>3.072284e+10</td>
# <td><blockquote>
# <p>0.016968</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>In [24]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>Out[24]:</td>
# <td><blockquote>
# <p>0.004478285900740008</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>In [25]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>Out[25]:</td>
# <td><blockquote>
# <p>&lt;AxesSubplot:&gt;</p>
# </blockquote></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>xrp_data<strong>.</strong>tail()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p><em>#viewing the average return from XRP</em><br />
# np<strong>.</strong>mean(xrp_data['Return'])</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>xrp_data['Return']<strong>.</strong>plot(style<strong>=</strong>"k.")</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image5.png" style="width:4.05417in;height:2.58611in" />
# >
# > **(c) Plotting the Closing Price Series for BTC**
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>localhost:8888/nbconvert/html/Data_Web_Mining/Project/Crypto Trading and Analysis (EDA).ipynb?download=false 10/14</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# | 5/1/22, 11:11 AM | Crypto Trading and Analysis (EDA) |
# |------------------|-----------------------------------|
# | In \[26\]:       |                                   |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>pl1 <strong>=</strong> btc_data['Close']<strong>.</strong>plot(style<strong>=</strong>['-'])</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image6.png" style="width:4.04444in;height:2.58472in" />
# >
# > **(d) Plotting the closing price series for XRP**
#
# |            |     |
# |------------|-----|
# | In \[27\]: |     |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>pl2 <strong>=</strong> xrp_data['Close']<strong>.</strong>plot(style <strong>=</strong>['-'])</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image7.png" style="width:3.97083in;height:2.60694in" />
# >
# > **7. Plotting the predicted and actual value**
# >
# > **Single Exponential Smoothing, SES for short, is a time series
# > forecasting method for univariate data without a trend or seasonality.
# > It requires a single parameter, called alpha**
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>localhost:8888/nbconvert/html/Data_Web_Mining/Project/Crypto Trading and Analysis (EDA).ipynb?download=false</p>
# </blockquote></td>
# <td>11/14</td>
# </tr>
# </tbody>
# </table>
#
# |                  |                                   |
# |------------------|-----------------------------------|
# | 5/1/22, 11:11 AM | Crypto Trading and Analysis (EDA) |
#
# > **(a), also called the smoothing factor or smoothing coefficient.**
# >
# > **We will be using SES for forecasting the closing values of the
# > crypto currencies**
#
# <table>
# <thead>
# <tr class="header">
# <th>In [47]:</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>C:\Users\mohit\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>be handled at model creation</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>warnings.warn(</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>Out[47]:</td>
# <td><blockquote>
# <p>&lt;AxesSubplot:&gt;</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p><em># Plotting the Pedicted and actual value for Bitcoin</em><br />
# <strong>from</strong> statsmodels.tsa.holtwinters <strong>import</strong> SimpleExpSmoothing<br />
# model <strong>=</strong> SimpleExpSmoothing(btc_data['Close'])<strong>.</strong>fit(smoothing_level<strong>=</strong>.01, optimized<strong>=False</strong>) btc_data['Close']<strong>.</strong>plot(style <strong>=</strong>['-'], color <strong>=</strong>'red')<br />
# model<strong>.</strong>fittedvalues<strong>.</strong>plot(style <strong>=</strong>['-'], color <strong>=</strong>'blue')</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image8.png" style="width:4.04444in;height:2.58472in" />
# >
# > **In the above figure, the red line shows the actual price while the
# > blue line shows the predicted line.**
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [48]:</p>
# <p>localhost:8888/nbconvert/html/Data_Web_Mining/Project/Crypto Trading and Analysis (EDA).ipynb?download=false 12/14</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p><em># Plotting the Pedicted and actual value for XRP</em><br />
# <strong>from</strong> statsmodels.tsa.holtwinters <strong>import</strong> SimpleExpSmoothing<br />
# model <strong>=</strong> SimpleExpSmoothing(xrp_data['Close'])<strong>.</strong>fit(smoothing_level<strong>=</strong>.01, optimized<strong>=False</strong>)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image10.png" style="width:6.37917in;height:4.40913in" />
#
# <table>
# <thead>
# <tr class="header">
# <th>5/1/22, 11:11 AM</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>C:\Users\mohit\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>be handled at model creation</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>warnings.warn(</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>Out[48]:</td>
# <td><blockquote>
# <p>&lt;AxesSubplot:&gt;</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><p>Crypto Trading and Analysis (EDA)</p>
# <blockquote>
# <p>xrp_data['Close']<strong>.</strong>plot(style <strong>=</strong>['-'], color <strong>=</strong>'red')<br />
# model<strong>.</strong>fittedvalues<strong>.</strong>plot(style <strong>=</strong>['-'], color <strong>=</strong>'blue')</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image9.png" style="width:3.97083in;height:2.60556in" />
# >
# > **In the above figure, the red line shows the actual price while the
# > blue line shows the predicted line.**
# >
# > **8. Finding relationship between BTC and XRP Returns using Linear
# > Regression**
#
# <table>
# <thead>
# <tr class="header">
# <th>In [78]:</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>localhost:8888/nbconvert/html/Data_Web_Mining/Project/Crypto Trading and Analysis (EDA).ipynb?download=false</p>
# </blockquote></td>
# <td>13/14</td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p><strong>import</strong> seaborn <strong>as</strong> sns<br />
# fig, ax <strong>=</strong> plt<strong>.</strong>subplots(figsize<strong>=</strong>(10,7))<br />
# btc_return <strong>=</strong> btc_data['Close']<strong>.</strong>pct_change()<strong>.</strong>dropna()<br />
# xrp_return <strong>=</strong> xrp_data['Close']<strong>.</strong>pct_change()<strong>.</strong>dropna()<br />
# regplot <strong>=</strong> sns<strong>.</strong>regplot(x<strong>=</strong>btc_return[:2800], y<strong>=</strong>xrp_return[:2800], color <strong>=</strong>'g', marker <strong>=</strong>'+') regplot<strong>.</strong>set(xlabel <strong>=</strong>'BTC % Return', ylabel <strong>=</strong>'XRP % Return')<br />
# sns<strong>.</strong>set_style("whitegrid")</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |                  |                                   |
# |------------------|-----------------------------------|
# | 5/1/22, 11:11 AM | Crypto Trading and Analysis (EDA) |
#
# > <img src="attachment:vertopal_bc14bd5b6ab44dde8aef61ad983125f5/media/image10.png" style="width:6.37917in;height:4.40972in" />
# >
# > **So, from the above we can see that both XRP and BTC returns are
# > highly correlated.**
#
# <table>
# <thead>
# <tr class="header">
# <th>In [ ]:</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>localhost:8888/nbconvert/html/Data_Web_Mining/Project/Crypto Trading and Analysis (EDA).ipynb?download=false</p>
# </blockquote></td>
# <td>14/14</td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
